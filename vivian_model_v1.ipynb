# %%
# %matplotlib inline
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split,ShuffleSplit
from sklearn.metrics import r2_score
from sklearn import ensemble
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

# %%
# ignore warnings from pandas
import warnings
warnings.filterwarnings('ignore')

# %%
df_train_raw = pd.read_csv("./data/train.csv")
df_test_raw = pd.read_csv("./data/data_for_test.csv")

# %%
#df_train = df_train_raw.groupby(['key']).mean().reset_index()

# %%
df_train_raw['xx1_roll'] = df_train_raw['xx1'].rolling(3).median()
df_train_raw['xx2_roll'] = df_train_raw['xx2'].rolling(3).median() 
df_train_raw['xx3_roll'] = df_train_raw['xx3'].rolling(3).median() 
df_train_raw['xx4_roll'] = df_train_raw['xx4'].rolling(3).median() 
df_train_raw['xx5_roll'] = df_train_raw['xx5'].rolling(3).median()

# %%
df_train_raw.head()
# Out:
#    patient_id     key  gender  age  x1  x2  x3  x4  x5  x6  ...   xx3   xx4  \
# 0        1891  1891-3       1   75  22   1   2   0   0   1  ...  99.9  49.4
# 1        1891  1891-3       1   75  22   1   2   0   0   1  ...  98.4  48.7
# 2        1891  1891-3       1   75  22   1   2   0   0   1  ...  95.3  48.5
# 3        1891  1891-3       1   75  22   1   2   0   0   1  ...  97.4  48.9
# 4        1891  1891-3       1   75  22   1   2   0   0   1  ...  99.6  50.2
#
#     xx5  y_mean_MAP  y_mean_HR  xx1_roll  xx2_roll  xx3_roll  xx4_roll  \
# 0  62.5       59.04       80.0       NaN       NaN       NaN       NaN
# 1  61.3       59.04       80.0       NaN       NaN       NaN       NaN
# 2  60.3       59.04       80.0      80.0      95.0      98.4      48.7
# 3  61.3       59.04       80.0      80.0      95.0      97.4      48.7
# 4  62.8       59.04       80.0      80.0      95.0      97.4      48.9
#
#    xx5_roll
# 0       NaN
# 1       NaN
# 2      61.3
# 3      61.3
# 4      61.3
#
# [5 rows x 22 columns]

# %%
df_train = df_train_raw.groupby(['key']).mean().reset_index()

# %%
df2 = df_train_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[1:2]).reset_index()
df2.columns = ['key','level','xx1_1','xx2_1','xx3_1','xx4_1','xx5_1']
df2.drop(['level'], axis = 1, inplace = True)
df_train = df_train.merge(df2, on = 'key', how = 'left')

df3 = df_train_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[2:3]).reset_index()
df3.columns = ['key','level','xx1_2','xx2_2','xx3_2','xx4_2','xx5_2']
df3.drop(['level'], axis = 1, inplace = True)
df_train = df_train.merge(df3, on = 'key', how = 'left')

df4 = df_train_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[3:4]).reset_index()
df4.columns = ['key','level','xx1_3','xx2_3','xx3_3','xx4_3','xx5_3']
df4.drop(['level'], axis = 1, inplace = True)
df_train = df_train.merge(df4, on = 'key', how = 'left')

df5 = df_train_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[4:5]).reset_index()
df5.columns = ['key','level','xx1_4','xx2_4','xx3_4','xx4_4','xx5_4']
df5.drop(['level'], axis = 1, inplace = True)
df_train = df_train.merge(df5, on = 'key', how = 'left')

# %%
df2 = df_train_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[-2:-1]).reset_index()
df2.columns = ['key','level','xx1_2l','xx2_2l','xx3_2l','xx4_2l','xx5_2l']
df2.drop(['level'], axis = 1, inplace = True)
df_train = df_train.merge(df2, on = 'key', how = 'left')

df3 = df_train_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[-3:-2]).reset_index()
df3.columns = ['key','level','xx1_3l','xx2_3l','xx3_3l','xx4_3l','xx5_3l']
df3.drop(['level'], axis = 1, inplace = True)
df_train = df_train.merge(df3, on = 'key', how = 'left')

df4 = df_train_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[-4:-3]).reset_index()
df4.columns = ['key','level','xx1_4l','xx2_4l','xx3_4l','xx4_4l','xx5_4l']
df4.drop(['level'], axis = 1, inplace = True)
df_train = df_train.merge(df4, on = 'key', how = 'left')

df5 = df_train_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[-5:-4]).reset_index()
df5.columns = ['key','level','xx1_5l','xx2_5l','xx3_5l','xx4_5l','xx5_5l']
df5.drop(['level'], axis = 1, inplace = True)
df_train = df_train.merge(df5, on = 'key', how = 'left')

df6 = df_train_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[-6:-5]).reset_index()
df6.columns = ['key','level','xx1_6l','xx2_6l','xx3_6l','xx4_6l','xx5_6l']
df6.drop(['level'], axis = 1, inplace = True)
df_train = df_train.merge(df6, on = 'key', how = 'left')

# %%
df1 = df_train_raw.groupby('key').tail(5).reset_index()
ts = df1.groupby(["key"]).agg({'xx1':['median','min','max'],'xx2':['median','min','max'],
                         'xx3':['median','min','max'], 'xx4':['median','min','max'],
                         'xx5':['median','min','max']}).reset_index()
ts.columns = ['key','xx1_10_median','xx1_10_min','xx1_10_max',
             'xx2_10_median','xx2_10_min','xx2_10_max',
             'xx3_10_median','xx3_10_min', 'xx3_10_max',
             'xx4_10_median','xx4_10_min','xx4_10_max',
             'xx5_10_median','xx5_10_min','xx5_10_max']

# %%
df_train = df_train.merge(ts, on = 'key', how = 'left')

# %%
stats = df_train_raw.groupby(['patient_id','key']).agg({'xx1':['last','first'],'xx2':['last','first'],
                                                        'xx3':['last','first'],'xx4':['last','first'],
                                                        'xx5':['last','first']}).reset_index()
stats.columns = ['patient_id','key','xx1_last','xx1_first','xx2_last','xx2_first',
                 'xx3_last','xx3_first','xx4_last','xx4_first','xx5_last','xx5_first']
stats.drop(['patient_id'], axis = 1, inplace = True)
df_train = df_train.merge(stats, on = 'key', how = 'left')

# %%
df_train.head()
# Out:
#     key  patient_id  gender  age  x1  x2  x3  x4  x5  x6  ...  xx1_last  \
# 0  0-28           0       0   72  39   5   1   0   0   0  ...      79.0
# 1  1-10           1       1   64  55   9   5   1   0   1  ...      71.0
# 2  1-11           1       1   64  55   9   5   1   0   1  ...      73.0
# 3  1-14           1       1   64  55   9   5   1   0   1  ...     119.0
# 4  1-15           1       1   64  55   9   5   1   0   1  ...     190.0
#
#    xx1_first  xx2_last  xx2_first  xx3_last  xx3_first  xx4_last  xx4_first  \
# 0       82.0     100.0      100.0     112.0      124.0      71.0       69.0
# 1       64.0     100.0      100.0     109.0      117.0      58.0       61.0
# 2       70.0     100.0      100.0     117.0      108.0      61.0       58.0
# 3       87.0     100.0      100.0     116.0      134.0      70.0       68.0
# 4      123.0     100.0      100.0     133.0      117.0      85.0       71.0
#
#    xx5_last  xx5_first
# 0      88.0       89.0
# 1      73.0       79.0
# 2      77.0       73.0
# 3      82.0       83.0
# 4      99.0       83.0
#
# [5 rows x 92 columns]

# %%
df_train.columns
# Out:
# Index(['key', 'patient_id', 'gender', 'age', 'x1', 'x2', 'x3', 'x4', 'x5',
#        'x6', 'xx1', 'xx2', 'xx3', 'xx4', 'xx5', 'y_mean_MAP', 'y_mean_HR',
#        'xx1_roll', 'xx2_roll', 'xx3_roll', 'xx4_roll', 'xx5_roll', 'xx1_1',
#        'xx2_1', 'xx3_1', 'xx4_1', 'xx5_1', 'xx1_2', 'xx2_2', 'xx3_2', 'xx4_2',
#        'xx5_2', 'xx1_3', 'xx2_3', 'xx3_3', 'xx4_3', 'xx5_3', 'xx1_4', 'xx2_4',
#        'xx3_4', 'xx4_4', 'xx5_4', 'xx1_2l', 'xx2_2l', 'xx3_2l', 'xx4_2l',
#        'xx5_2l', 'xx1_3l', 'xx2_3l', 'xx3_3l', 'xx4_3l', 'xx5_3l', 'xx1_4l',
#        'xx2_4l', 'xx3_4l', 'xx4_4l', 'xx5_4l', 'xx1_5l', 'xx2_5l', 'xx3_5l',
#        'xx4_5l', 'xx5_5l', 'xx1_6l', 'xx2_6l', 'xx3_6l', 'xx4_6l', 'xx5_6l',
#        'xx1_10_median', 'xx1_10_min', 'xx1_10_max', 'xx2_10_median',
#        'xx2_10_min', 'xx2_10_max', 'xx3_10_median', 'xx3_10_min', 'xx3_10_max',
#        'xx4_10_median', 'xx4_10_min', 'xx4_10_max', 'xx5_10_median',
#        'xx5_10_min', 'xx5_10_max', 'xx1_last', 'xx1_first', 'xx2_last',
#        'xx2_first', 'xx3_last', 'xx3_first', 'xx4_last', 'xx4_first',
#        'xx5_last', 'xx5_first'],
#       dtype='object')

# %%
#drop target column
df_train.drop(['y_mean_HR','y_mean_MAP'], axis = 1, inplace = True)

# %%
df_train.shape
# Out:
# (44949, 90)

# %%
valid_idx = range(int(df_train.shape[0]*80/100), df_train.shape[0])
train_idx = range(int(df_train.shape[0]*80/100))

# %%
#specify Target
y_mean_MAP = df_train_raw[['y_mean_MAP','key']].groupby('key').mean().reset_index().drop(['key'], axis = 1)
y_mean_HR = df_train_raw[['y_mean_HR','key']].groupby('key').mean().reset_index().drop(['key'], axis = 1)

# %%
#Train Test Split
X_map_train = df_train.loc[train_idx,:]
X_map_val = df_train.loc[valid_idx,:]
y_map_train = y_mean_MAP.loc[train_idx]
y_map_val = y_mean_MAP.loc[valid_idx]

# %%
X_hr_train = df_train.loc[train_idx,:]
X_hr_val = df_train.loc[valid_idx,:]
y_hr_train = y_mean_HR.loc[train_idx]
y_hr_val = y_mean_HR.loc[valid_idx]

# %%
#Sanity Check
print(X_map_train.key.isin(X_map_val.key).all())
print(X_hr_train.key.isin(X_hr_val.key).all())
# Out:
# False
# False

# %%
X_map_train = X_map_train.drop(['key','patient_id'],axis = 1)
X_map_val = X_map_val.drop(['key','patient_id'],axis = 1)
X_hr_train = X_hr_train.drop(['key','patient_id'],axis = 1)
X_hr_val = X_hr_val.drop(['key','patient_id'],axis = 1)

# %%
X_map_train.shape
# Out:
# (35959, 88)

# %%
X_map_train.head()
# Out:
#    gender  age  x1  x2  x3  x4  x5  x6         xx1         xx2  ...  xx1_last  \
# 0       0   72  39   5   1   0   0   0   80.166667   99.733333  ...      79.0
# 1       1   64  55   9   5   1   0   1   72.100000   99.800000  ...      71.0
# 2       1   64  55   9   5   1   0   1   71.500000   99.966667  ...      73.0
# 3       1   64  55   9   5   1   0   1   99.133333  100.000000  ...     119.0
# 4       1   64  55   9   5   1   0   1  150.200000  100.000000  ...     190.0
#
#    xx1_first  xx2_last  xx2_first  xx3_last  xx3_first  xx4_last  xx4_first  \
# 0       82.0     100.0      100.0     112.0      124.0      71.0       69.0
# 1       64.0     100.0      100.0     109.0      117.0      58.0       61.0
# 2       70.0     100.0      100.0     117.0      108.0      61.0       58.0
# 3       87.0     100.0      100.0     116.0      134.0      70.0       68.0
# 4      123.0     100.0      100.0     133.0      117.0      85.0       71.0
#
#    xx5_last  xx5_first
# 0      88.0       89.0
# 1      73.0       79.0
# 2      77.0       73.0
# 3      82.0       83.0
# 4      99.0       83.0
#
# [5 rows x 88 columns]

# %% [markdown]
# ### Deep learning model y_mean_MAP

# %%
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from keras.layers import Dropout
from keras import optimizers

# %%
model = Sequential()
model.add(Dense(88, input_dim=88, kernel_initializer='normal', activation='relu'))
model.add(Dense(77, kernel_initializer='normal', activation='relu'))
#model.add(Dense(37, kernel_initializer='normal', activation='relu'))
model.add(Dense(1, kernel_initializer='normal'))
# Compile model

adam = optimizers.Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(loss='mse', optimizer=adam, metrics=['mse','mae'])
history = model.fit(X_map_train, y_map_train, epochs=100, batch_size=50,  verbose=1, validation_data = (X_map_val,y_map_val))
# Out:
# Train on 35959 samples, validate on 8990 samples
# Epoch 1/100
# 35959/35959 [==============================] - 1s 22us/step - loss: 161.2282 - mse: 161.2281 - mae: 6.4536 - val_loss: 27.1920 - val_mse: 27.1920 - val_mae: 3.3841
# Epoch 2/100
# 35959/35959 [==============================] - 1s 18us/step - loss: 26.2772 - mse: 26.2772 - mae: 3.3122 - val_loss: 24.1360 - val_mse: 24.1360 - val_mae: 2.9763
# 35959/35959 [==============================] - 1s 17us/step - loss: 20.9907 - mse: 20.9907 - mae: 2.6811 - val_loss: 22.3894 - val_mse: 22.3894 - val_mae: 2.7941
# Epoch 97/100
# 35959/35959 [==============================] - 1s 17us/step - loss: 20.9257 - mse: 20.9257 - mae: 2.6712 - val_loss: 21.8187 - val_mse: 21.8187 - val_mae: 2.6879
# Epoch 98/100
# 35959/35959 [==============================] - 1s 17us/step - loss: 20.9872 - mse: 20.9872 - mae: 2.6878 - val_loss: 20.8444 - val_mse: 20.8444 - val_mae: 2.5728
# Epoch 99/100
# 35959/35959 [==============================] - 1s 18us/step - loss: 21.0719 - mse: 21.0719 - mae: 2.7036 - val_loss: 21.8212 - val_mse: 21.8212 - val_mae: 2.8518
# Epoch 100/100
# 35959/35959 [==============================] - 1s 17us/step - loss: 20.8945 - mse: 20.8945 - mae: 2.6795 - val_loss: 21.0757 - val_mse: 21.0757 - val_mae: 2.5652

# %%
y_map_val_pred = model.predict(X_map_val)
r2_score(y_map_val,y_map_val_pred)
# Out:
# 0.8898083934823475

# %% [markdown]
# ### Deep learning Model y_mean_HR

# %%
model_hr = Sequential()
model_hr.add(Dense(38, input_dim=38, kernel_initializer='normal', activation='relu'))
model_hr.add(Dense(33, kernel_initializer='normal', activation='relu'))
model_hr.add(Dense(1, kernel_initializer='normal'))
    # Compile model
adam = optimizers.Adam(learning_rate=0.003, beta_1=0.9, beta_2=0.999, amsgrad=False)
model_hr.compile(loss='mse', optimizer=adam, metrics=['mse','mae'])
history_hr = model_hr.fit(X_hr_train, y_hr_train, epochs=100, batch_size=50,  verbose=1, validation_data = (X_hr_val,y_hr_val))
# Out:
# Train on 35959 samples, validate on 8990 samples
# Epoch 1/100
# 35959/35959 [==============================] - 1s 19us/step - loss: 152.0473 - mse: 152.0473 - mae: 5.3234 - val_loss: 12.1353 - val_mse: 12.1353 - val_mae: 1.7582
# Epoch 2/100
# 35959/35959 [==============================] - 1s 15us/step - loss: 15.4673 - mse: 15.4673 - mae: 1.9997 - val_loss: 21.1086 - val_mse: 21.1086 - val_mae: 3.4918
# Epoch 3/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 16.0179 - mse: 16.0179 - mae: 2.1351 - val_loss: 17.4095 - val_mse: 17.4095 - val_mae: 2.9049
# Epoch 4/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.9084 - mse: 15.9084 - mae: 2.1424 - val_loss: 13.6575 - val_mse: 13.6575 - val_mae: 2.1951
# Epoch 5/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.8705 - mse: 15.8705 - mae: 2.1356 - val_loss: 13.1756 - val_mse: 13.1756 - val_mae: 2.0790
# Epoch 6/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 16.2407 - mse: 16.2407 - mae: 2.1909 - val_loss: 13.2114 - val_mse: 13.2114 - val_mae: 2.1106
# Epoch 7/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.9827 - mse: 15.9827 - mae: 2.1826 - val_loss: 16.6770 - val_mse: 16.6770 - val_mae: 2.8048
# Epoch 8/100
# 35959/35959 [==============================] - 1s 15us/step - loss: 15.9120 - mse: 15.9120 - mae: 2.1342 - val_loss: 11.7308 - val_mse: 11.7308 - val_mae: 1.6622
# Epoch 9/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.7428 - mse: 15.7429 - mae: 2.1138 - val_loss: 11.5417 - val_mse: 11.5417 - val_mae: 1.6085
# Epoch 10/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.8918 - mse: 15.8918 - mae: 2.1627 - val_loss: 13.8094 - val_mse: 13.8094 - val_mae: 2.2269
# Epoch 11/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.6788 - mse: 15.6788 - mae: 2.1170 - val_loss: 12.6321 - val_mse: 12.6321 - val_mae: 1.9605
# Epoch 12/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.8346 - mse: 15.8346 - mae: 2.1408 - val_loss: 17.5343 - val_mse: 17.5343 - val_mae: 2.9577
# Epoch 13/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.7019 - mse: 15.7019 - mae: 2.1169 - val_loss: 12.9454 - val_mse: 12.9454 - val_mae: 2.0498
# Epoch 14/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.8903 - mse: 15.8903 - mae: 2.1520 - val_loss: 14.1837 - val_mse: 14.1837 - val_mae: 2.3534
# Epoch 15/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.9533 - mse: 15.9533 - mae: 2.1601 - val_loss: 12.0535 - val_mse: 12.0535 - val_mae: 1.8071
# Epoch 16/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.4362 - mse: 15.4362 - mae: 2.0615 - val_loss: 16.3819 - val_mse: 16.3819 - val_mae: 2.7624
# Epoch 17/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.6198 - mse: 15.6198 - mae: 2.1130 - val_loss: 11.9527 - val_mse: 11.9527 - val_mae: 1.7805
# Epoch 18/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.5401 - mse: 15.5401 - mae: 2.0872 - val_loss: 11.4826 - val_mse: 11.4826 - val_mae: 1.6311
# Epoch 19/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.4110 - mse: 15.4110 - mae: 2.0703 - val_loss: 12.1564 - val_mse: 12.1564 - val_mae: 1.8594
# Epoch 20/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.6189 - mse: 15.6189 - mae: 2.1126 - val_loss: 13.4972 - val_mse: 13.4972 - val_mae: 2.2127
# Epoch 21/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.4186 - mse: 15.4186 - mae: 2.0659 - val_loss: 12.5850 - val_mse: 12.5850 - val_mae: 1.9717
# Epoch 22/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.1396 - mse: 15.1396 - mae: 1.9958 - val_loss: 12.8863 - val_mse: 12.8863 - val_mae: 2.0716
# Epoch 23/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 15.2465 - mse: 15.2465 - mae: 2.0344 - val_loss: 14.3504 - val_mse: 14.3504 - val_mae: 2.3898
# 35959/35959 [==============================] - 1s 15us/step - loss: 14.5396 - mse: 14.5396 - mae: 1.9042 - val_loss: 11.8779 - val_mse: 11.8779 - val_mae: 1.8001
# Epoch 87/100
# 35959/35959 [==============================] - 1s 15us/step - loss: 14.5356 - mse: 14.5356 - mae: 1.9074 - val_loss: 12.7623 - val_mse: 12.7623 - val_mae: 2.0531
# Epoch 88/100
# 35959/35959 [==============================] - 1s 15us/step - loss: 14.7867 - mse: 14.7867 - mae: 1.9511 - val_loss: 11.2892 - val_mse: 11.2892 - val_mae: 1.5877
# Epoch 89/100
# 35959/35959 [==============================] - 1s 15us/step - loss: 14.4726 - mse: 14.4726 - mae: 1.8890 - val_loss: 12.7596 - val_mse: 12.7596 - val_mae: 2.0686
# Epoch 90/100
# 35959/35959 [==============================] - 1s 15us/step - loss: 14.5585 - mse: 14.5585 - mae: 1.9050 - val_loss: 11.2301 - val_mse: 11.2301 - val_mae: 1.5760
# Epoch 91/100
# 35959/35959 [==============================] - 1s 15us/step - loss: 14.5077 - mse: 14.5077 - mae: 1.8934 - val_loss: 11.7832 - val_mse: 11.7832 - val_mae: 1.7789
# Epoch 92/100
# 35959/35959 [==============================] - 1s 15us/step - loss: 14.4737 - mse: 14.4737 - mae: 1.8898 - val_loss: 11.8202 - val_mse: 11.8202 - val_mae: 1.8158
# Epoch 93/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 14.4957 - mse: 14.4957 - mae: 1.8847 - val_loss: 11.3532 - val_mse: 11.3532 - val_mae: 1.6478
# Epoch 94/100
# 35959/35959 [==============================] - 1s 15us/step - loss: 14.5227 - mse: 14.5227 - mae: 1.8868 - val_loss: 11.9794 - val_mse: 11.9794 - val_mae: 1.8408
# Epoch 95/100
# 35959/35959 [==============================] - 1s 15us/step - loss: 14.5652 - mse: 14.5652 - mae: 1.8970 - val_loss: 11.3784 - val_mse: 11.3784 - val_mae: 1.6604
# Epoch 96/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 14.4482 - mse: 14.4482 - mae: 1.8835 - val_loss: 11.9070 - val_mse: 11.9070 - val_mae: 1.8214
# Epoch 97/100
# 35959/35959 [==============================] - 1s 16us/step - loss: 14.4980 - mse: 14.4980 - mae: 1.8894 - val_loss: 12.7284 - val_mse: 12.7284 - val_mae: 2.0731
# Epoch 98/100
# 35959/35959 [==============================] - 1s 15us/step - loss: 14.6966 - mse: 14.6966 - mae: 1.9406 - val_loss: 11.5969 - val_mse: 11.5969 - val_mae: 1.7252
# Epoch 99/100
# 35959/35959 [==============================] - 1s 15us/step - loss: 14.5792 - mse: 14.5792 - mae: 1.9147 - val_loss: 14.2508 - val_mse: 14.2508 - val_mae: 2.4048
# Epoch 100/100
# 35959/35959 [==============================] - 1s 15us/step - loss: 14.5852 - mse: 14.5852 - mae: 1.9275 - val_loss: 11.2929 - val_mse: 11.2929 - val_mae: 1.6277- loss: 12.7902 - mse: 12.7902 - mae:

# %%
y_hr_val_pred = model_hr.predict(X_hr_val)
r2_score(y_hr_val,y_hr_val_pred)
# Out:
# 0.9528174450328679

# %% [markdown]
# ### XGBoost on y_mean_MAP

# %%
#feature selection
X_map_train.columns

# %%
# X_map_train = X_map_train[['gender','age','x1','x2','xx3','xx4','xx5','xx3_mean','xx3_last',
#                    'xx4_mean','xx4_last','xx5_mean','xx5_last']]
# X_map_val = X_map_val[['gender','age','x1','x2','xx3','xx4','xx5','xx3_mean','xx3_last',
#                    'xx4_mean','xx4_last','xx5_mean','xx5_last']]
X_map_train = X_map_train.drop(['key','patient_id'],axis = 1)
X_map_val = X_map_val.drop(['key','patient_id'],axis = 1)

# %%
params = {'learning_rate':[0.03,0.01,0.1,0.5],
            'n_estimator':[200,500,1000,1500]}

xgb_map = xgb.XGBRegressor(nthread=-1) 

grid_map = GridSearchCV(xgb_map, params)
grid_map.fit(X_map_train,y_map_train)
# Out:
# [22:15:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:15:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:15:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:15:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:15:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:15:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:15:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:15:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:15:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:16:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:16:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:16:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:16:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:16:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:16:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:16:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:16:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:17:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:17:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:17:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:17:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:17:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:17:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:17:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:17:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:18:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:18:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:18:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:18:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:18:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:18:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:18:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:18:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:19:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:19:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:19:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:19:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:19:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:19:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:19:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:19:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:20:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:20:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:20:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:20:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:20:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:20:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:20:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:20:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=-1,
#                                     objective='reg:linear', random_state=0,
#                                     reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=1, seed=None, silent=None,
#                                     subsample=1, verbosity=1),
#              iid='warn', n_jobs=None,
#              param_grid={'learning_rate': [0.03, 0.01, 0.1, 0.5],
#                          'n_estimator': [200, 500, 1000, 1500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print(r2_score(y_map_val, grid_map.best_estimator_.predict(X_map_val)))
# Out:
# 0.8899259083074982

# %%
xgb_map = xgb.XGBRegressor(colsample_bytree=0.4,
                 gamma=0,                 
                 learning_rate=0.005,
                 max_depth=7,
                 min_child_weight=5,
                 n_estimators=2000,                                                                    
                 reg_alpha=0.75,
                 reg_lambda=0.45,
                 subsample=0.7,
                 seed=42)
xgb_map.fit(X_map_train,y_map_train)
# Out:
# [11:57:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.4, gamma=0,
#              importance_type='gain', learning_rate=0.005, max_delta_step=0,
#              max_depth=7, min_child_weight=5, missing=None, n_estimators=2000,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0.75, reg_lambda=0.45, scale_pos_weight=1, seed=42,
#              silent=None, subsample=0.7, verbosity=1)

# %%
y_map_val_pred = xgb_map.predict(X_map_val)
r2_score(y_map_val,y_map_val_pred)
# Out:
# 0.8920430761193813

# %%
y_map_val_pred = xgb_map.predict(X_map_val)
r2_score(y_map_val,y_map_val_pred)
# Out:
# 0.8917243439670166

# %% [markdown]
# ### XGBoost on y_mean_HR

# %%
params = {'learning_rate':[0.03,0.01,0.1,0.5],  
          'subsample':[i/10.0 for i in range(6,11)],
            'n_estimator':[200,500,1000,1500], 
            'max_depth': [2,3,4]}

xgb_hr = xgb.XGBRegressor(nthread=-1) 

grid_hr = GridSearchCV(xgb_hr, params)
grid_hr.fit(X_hr_train,y_hr_train)

# %%
print(r2_score(y_hr_val, grid_hr.best_estimator_.predict(X_hr_val)))

# %%
xgb_hr = xgb.XGBRegressor(colsample_bytree=0.4,
                 gamma=0,                 
                 learning_rate=0.005,
                 max_depth=5,
                 min_child_weight=1.5,
                 n_estimators=2000,                                                                    
                 reg_alpha=0.75,
                 reg_lambda=0.45,
                 subsample=0.6,
                 seed=42)
xgb_hr.fit(X_hr_train,y_hr_train)
# Out:
# [11:00:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.4, gamma=0,
#              importance_type='gain', learning_rate=0.005, max_delta_step=0,
#              max_depth=5, min_child_weight=1.5, missing=None, n_estimators=2000,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0.75, reg_lambda=0.45, scale_pos_weight=1, seed=42,
#              silent=None, subsample=0.6, verbosity=1)

# %%
y_hr_val_pred = xgb_hr.predict(X_hr_val)
r2_score(y_hr_val,y_hr_val_pred)
# Out:
# 0.9542176689957953

# %% [markdown]
# ### Test

# %%
df_test_raw['xx1_roll'] = df_test_raw['xx1'].rolling(3).mean()
df_test_raw['xx2_roll'] = df_test_raw['xx2'].rolling(3).mean() 
df_test_raw['xx3_roll'] = df_test_raw['xx3'].rolling(3).mean() 
df_test_raw['xx4_roll'] = df_test_raw['xx4'].rolling(3).mean() 
df_test_raw['xx5_roll'] = df_test_raw['xx5'].rolling(3).mean()

# %%
df_test = df_test_raw.groupby(['key']).mean().reset_index()

# %%
df_test.head()
# Out:
#        key  patient_id  gender  age  x1  x2  x3  x4  x5  x6        xx1  \
# 0   1005-1        1005       0   80  41   4   2   1   0   0  57.866667
# 1  1005-10        1005       0   80  41   4   2   0   0   0  75.766667
# 2  1005-11        1005       0   80  41   4   2   1   0   0  65.666667
# 3  1005-12        1005       0   80  41   4   2   1   0   0  64.600000
# 4  1005-13        1005       0   80  41   4   2   0   0   0  73.800000
#
#          xx2         xx3        xx4        xx5   xx1_roll   xx2_roll  \
# 0  98.433333  126.566667  42.800000  71.466667  57.940476  98.416667
# 1  97.333333  126.933333  48.400000  71.866667  75.644444  97.077778
# 2  92.166667  109.000000  48.633333  65.600000  65.866667  92.488889
# 3  94.933333  124.200000  55.400000  75.133333  64.622222  94.688889
# 4  97.400000  134.733333  52.366667  77.200000  73.422222  97.322222
#
#      xx3_roll   xx4_roll   xx5_roll
# 0  127.250000  43.190476  71.988095
# 1  126.166667  48.377778  71.600000
# 2  109.722222  48.655556  65.833333
# 3  124.188889  55.444444  75.055556
# 4  133.777778  52.100000  76.811111

# %%
df2 = df_test_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[1:2]).reset_index()
df2.columns = ['key','level','xx1_1','xx2_1','xx3_1','xx4_1','xx5_1']
df2.drop(['level'], axis = 1, inplace = True)
df_test = df_test.merge(df2, on = 'key', how = 'left')

df3 = df_test_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[2:3]).reset_index()
df3.columns = ['key','level','xx1_2','xx2_2','xx3_2','xx4_2','xx5_2']
df3.drop(['level'], axis = 1, inplace = True)
df_test = df_test.merge(df3, on = 'key', how = 'left')

df4 = df_test_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[3:4]).reset_index()
df4.columns = ['key','level','xx1_3','xx2_3','xx3_3','xx4_3','xx5_3']
df4.drop(['level'], axis = 1, inplace = True)
df_test = df_test.merge(df4, on = 'key', how = 'left')

df5 = df_test_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[4:5]).reset_index()
df5.columns = ['key','level','xx1_4','xx2_4','xx3_4','xx4_4','xx5_4']
df5.drop(['level'], axis = 1, inplace = True)
df_test = df_test.merge(df5, on = 'key', how = 'left')

# %%
df2 = df_test_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[-2:-1]).reset_index()
df2.columns = ['key','level','xx1_2l','xx2_2l','xx3_2l','xx4_2l','xx5_2l']
df2.drop(['level'], axis = 1, inplace = True)
df_test = df_test.merge(df2, on = 'key', how = 'left')

df3 = df_test_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[-3:-2]).reset_index()
df3.columns = ['key','level','xx1_3l','xx2_3l','xx3_3l','xx4_3l','xx5_3l']
df3.drop(['level'], axis = 1, inplace = True)
df_test = df_test.merge(df3, on = 'key', how = 'left')

df4 = df_test_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[-4:-3]).reset_index()
df4.columns = ['key','level','xx1_4l','xx2_4l','xx3_4l','xx4_4l','xx5_4l']
df4.drop(['level'], axis = 1, inplace = True)
df_test = df_test.merge(df4, on = 'key', how = 'left')

df5 = df_test_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[-5:-4]).reset_index()
df5.columns = ['key','level','xx1_5l','xx2_5l','xx3_5l','xx4_5l','xx5_5l']
df5.drop(['level'], axis = 1, inplace = True)
df_test = df_test.merge(df5, on = 'key', how = 'left')

df6 = df_test_raw.groupby('key')[['xx1','xx2','xx3','xx4','xx5']].apply(lambda x : x[-6:-5]).reset_index()
df6.columns = ['key','level','xx1_6l','xx2_6l','xx3_6l','xx4_6l','xx5_6l']
df6.drop(['level'], axis = 1, inplace = True)
df_test = df_test.merge(df6, on = 'key', how = 'left')

# %%
df1 = df_test_raw.groupby('key').tail(5).reset_index()
ts = df1.groupby(["key"]).agg({'xx1':['median','min','max'],'xx2':['median','min','max'],
                         'xx3':['median','min','max'], 'xx4':['median','min','max'],
                         'xx5':['median','min','max']}).reset_index()
ts.columns = ['key','xx1_10_median','xx1_10_min','xx1_10_max',
             'xx2_10_median','xx2_10_min','xx2_10_max',
             'xx3_10_median','xx3_10_min', 'xx3_10_max',
             'xx4_10_median','xx4_10_min','xx4_10_max',
             'xx5_10_median','xx5_10_min','xx5_10_max']

# %%
df_test = df_test.merge(ts, on = 'key', how = 'left')

# %%
stats = df_test_raw.groupby(['patient_id','key']).agg({'xx1':['last','first'],'xx2':['last','first'],
                                                        'xx3':['last','first'],'xx4':['last','first'],
                                                        'xx5':['last','first']}).reset_index()
stats.columns = ['patient_id','key','xx1_last','xx1_first','xx2_last','xx2_first',
                 'xx3_last','xx3_first','xx4_last','xx4_first','xx5_last','xx5_first']
stats.drop(['patient_id'], axis = 1, inplace = True)
df_test = df_test.merge(stats, on = 'key', how = 'left')

# %%
df_test.head()
# Out:
#        key  patient_id  gender  age  x1  x2  x3  x4  x5  x6  ...  xx1_last  \
# 0   1005-1        1005       0   80  41   4   2   1   0   0  ...      55.0
# 1  1005-10        1005       0   80  41   4   2   0   0   0  ...      71.0
# 2  1005-11        1005       0   80  41   4   2   1   0   0  ...      65.0
# 3  1005-12        1005       0   80  41   4   2   1   0   0  ...      68.0
# 4  1005-13        1005       0   80  41   4   2   0   0   0  ...      76.0
#
#    xx1_first  xx2_last  xx2_first  xx3_last  xx3_first  xx4_last  xx4_first  \
# 0       59.0      99.0       99.0     116.0      118.0      36.0       38.0
# 1       77.0     100.0       97.0     124.0      130.0      46.0       50.0
# 2       71.0      89.0       94.0     105.0      118.0      46.0       52.0
# 3       67.0      97.0       95.0     108.0      118.0      47.0       72.0
# 4       70.0      99.0       97.0     132.0      132.0      52.0       49.0
#
#    xx5_last  xx5_first
# 0      61.0       66.0
# 1      68.0       74.0
# 2      62.0       71.0
# 3      68.0       83.0
# 4      76.0       73.0
#
# [5 rows x 90 columns]

# %%
df_test.columns
# Out:
# Index(['key', 'patient_id', 'gender', 'age', 'x1', 'x2', 'x3', 'x4', 'x5',
#        'x6', 'xx1', 'xx2', 'xx3', 'xx4', 'xx5', 'xx1_roll', 'xx2_roll',
#        'xx3_roll', 'xx4_roll', 'xx5_roll', 'xx1_1', 'xx2_1', 'xx3_1', 'xx4_1',
#        'xx5_1', 'xx1_2', 'xx2_2', 'xx3_2', 'xx4_2', 'xx5_2', 'xx1_3', 'xx2_3',
#        'xx3_3', 'xx4_3', 'xx5_3', 'xx1_4', 'xx2_4', 'xx3_4', 'xx4_4', 'xx5_4',
#        'xx1_2l', 'xx2_2l', 'xx3_2l', 'xx4_2l', 'xx5_2l', 'xx1_3l', 'xx2_3l',
#        'xx3_3l', 'xx4_3l', 'xx5_3l', 'xx1_4l', 'xx2_4l', 'xx3_4l', 'xx4_4l',
#        'xx5_4l', 'xx1_5l', 'xx2_5l', 'xx3_5l', 'xx4_5l', 'xx5_5l', 'xx1_6l',
#        'xx2_6l', 'xx3_6l', 'xx4_6l', 'xx5_6l', 'xx1_10_median', 'xx1_10_min',
#        'xx1_10_max', 'xx2_10_median', 'xx2_10_min', 'xx2_10_max',
#        'xx3_10_median', 'xx3_10_min', 'xx3_10_max', 'xx4_10_median',
#        'xx4_10_min', 'xx4_10_max', 'xx5_10_median', 'xx5_10_min', 'xx5_10_max',
#        'xx1_last', 'xx1_first', 'xx2_last', 'xx2_first', 'xx3_last',
#        'xx3_first', 'xx4_last', 'xx4_first', 'xx5_last', 'xx5_first',
#        'y_mean_MAP', 'y_mean_HR'],
#       dtype='object')

# %%
X_map_train.columns
# Out:
# Index(['gender', 'age', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'xx1', 'xx2',
#        'xx3', 'xx4', 'xx5', 'xx1_roll', 'xx2_roll', 'xx3_roll', 'xx4_roll',
#        'xx5_roll', 'xx1_1', 'xx2_1', 'xx3_1', 'xx4_1', 'xx5_1', 'xx1_2',
#        'xx2_2', 'xx3_2', 'xx4_2', 'xx5_2', 'xx1_3', 'xx2_3', 'xx3_3', 'xx4_3',
#        'xx5_3', 'xx1_4', 'xx2_4', 'xx3_4', 'xx4_4', 'xx5_4', 'xx1_2l',
#        'xx2_2l', 'xx3_2l', 'xx4_2l', 'xx5_2l', 'xx1_3l', 'xx2_3l', 'xx3_3l',
#        'xx4_3l', 'xx5_3l', 'xx1_4l', 'xx2_4l', 'xx3_4l', 'xx4_4l', 'xx5_4l',
#        'xx1_5l', 'xx2_5l', 'xx3_5l', 'xx4_5l', 'xx5_5l', 'xx1_6l', 'xx2_6l',
#        'xx3_6l', 'xx4_6l', 'xx5_6l', 'xx1_10_median', 'xx1_10_min',
#        'xx1_10_max', 'xx2_10_median', 'xx2_10_min', 'xx2_10_max',
#        'xx3_10_median', 'xx3_10_min', 'xx3_10_max', 'xx4_10_median',
#        'xx4_10_min', 'xx4_10_max', 'xx5_10_median', 'xx5_10_min', 'xx5_10_max',
#        'xx1_last', 'xx1_first', 'xx2_last', 'xx2_first', 'xx3_last',
#        'xx3_first', 'xx4_last', 'xx4_first', 'xx5_last', 'xx5_first'],
#       dtype='object')

# %%
test_map_pred = xgb_map.predict(df_test.drop(['key','patient_id'],axis = 1))

# %%
test_hr_pred = xgb_hr.predict(df_test.drop(['key','patient_id'],axis = 1))
#test_map_pred = model.predict(df_test)

# %%
df_test['y_mean_MAP'] = test_map_pred
df_test['y_mean_HR'] = test_hr_pred

# %%
df_submit = df_test[['key','y_mean_MAP','y_mean_HR']]

# %%
df_submit.head()
# Out:
#        key  y_mean_MAP  y_mean_HR
# 0   1005-1   63.459949  54.605846
# 1  1005-10   71.038574  75.385368
# 2  1005-11   64.454704  65.233551
# 3  1005-12   70.337440  61.704193
# 4  1005-13   76.873314  75.233749

# %%
df_submit = df_submit.groupby('key').mean()

# %%
df_submit.head()
# Out:
#          y_mean_MAP  y_mean_HR
# key
# 1005-1    63.459949  54.605846
# 1005-10   71.038574  75.385368
# 1005-11   64.454704  65.233551
# 1005-12   70.337440  61.704193
# 1005-13   76.873314  75.233749

# %%
df_submit.to_csv("no_one_10.csv")
